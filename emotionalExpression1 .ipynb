# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
from deepface import DeepFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9992a767273a> in <module>
# ----> 1 from deepface import DeepFace
#
# ModuleNotFoundError: No module named 'deepface'

# %%
img=cv2.imread('happy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2..COLOR_BGR2RGB))
# Out:
#   File "<ipython-input-7-155cabe84bea>", line 1
#     plt.imshow(cv2.cvtColor(img,cv2..COLOR_BGR2RGB))
#                                     ^
# SyntaxError: invalid syntax

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-15acfeec493b> in <module>
# ----> 1 plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
#
# NameError: name 'plt' is not defined

# %%
predictions=DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ccd3ac1912e4> in <module>
# ----> 1 predictions=DeepFace.analyze(img)
#
# NameError: name 'DeepFace' is not defined

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b09476414a5a> in <module>
# ----> 1 predictions = DeepFace.analyze(img)
#
# NameError: name 'img' is not defined
